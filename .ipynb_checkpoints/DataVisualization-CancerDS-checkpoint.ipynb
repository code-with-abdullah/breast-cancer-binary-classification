# %% [markdown]
# ## Preprocessing copied from Data Cleaning Notebook and altered

# %%
import os
import time
import shutil
import random

import numpy as np
import pandas as pd
from IPython.display import Image

import seaborn as sns
import matplotlib.pyplot as plt

# %%
total_folders = len(os.listdir("Fayyaz"))
print("Total number of folders containing images are", total_folders)
# Out:
# Total number of folders containing images are 279

# %%
main_folder = os.path.join(os.getcwd(), "Fayyaz") # folder that contains images in 281 folders
new_folder_path = os.path.join(os.getcwd(), "Preprocessed") # new folder containing all images

# %%
start_time = time.time()

positive_counter = 0
negative_counter = 0

positive_selected_images = []
negative_selected_images = []

images = os.listdir(new_folder_path)
print("Total number of images are: ", len(images))
# Out:
# Total number of images are:  277523

# %% [markdown]
# ### Selecting a random sample of 10 images

# %%
random.shuffle(images)

# %%
for image in images:
    if(negative_counter < 5):
        if (image[-5:] == "0.png"): # ends with 0.png means a negative sample
            negative_selected_images.append(image)
            negative_counter = negative_counter + 1
    if(positive_counter < 5):
        if (image[-5:] == "1.png"): # ends with 1.png means a positive sample
            positive_selected_images.append(image)
            positive_counter = positive_counter + 1
            
    if(positive_counter == 5 and negative_counter == 5):
        break   
        
end_time = time.time()

print("Time taken for running this code block", round(end_time - start_time, 2), " seconds")

print("")
print("")
print("Negative sample images : ", negative_selected_images)
print("")
print("Positive sample images : ", positive_selected_images)
# Out:
# Time taken for running this code block 0.44  seconds
#
#
# Negative sample images :  ['12242_idx5_x2651_y1551_class0.png', '10268_idx5_x2101_y801_class0.png', '10255_idx5_x1051_y1751_class0.png', '9259_idx5_x1801_y701_class0.png', '13459_idx5_x601_y1151_class0.png']
#
# Positive sample images :  ['9382_idx5_x1801_y1951_class1.png', '14209_idx5_x1151_y1601_class1.png', '15516_idx5_x2151_y1901_class1.png', '12824_idx5_x901_y651_class1.png', '12894_idx5_x1851_y1101_class1.png']

# %% [markdown]
# #### Visualize Positive and Negative images

# %%
import cv2

# %%
from collections import Counter

# %%
ncount = 1
print('Showing sample of negative images from data')
for image in negative_selected_images:
    IMG = cv2.imread(os.path.join(new_folder_path, image))
    resized = cv2.resize(IMG, (250, 250))
    
    plt.figure(figsize = (80, 5))
    plt.subplot(2, 20, ncount)
    ncount = ncount + 1
    plt.imshow(resized)
    plt.xlabel('Image')

    plt.subplot(2, 20, ncount)
    ncount = ncount + 1
    plt.hist(resized.ravel(), 256, [0, 256])
    plt.xlabel('Histogram')
    
    normalized_image = resized/255.0
    plt.subplot(2, 20, ncount)
    ncount = ncount + 1
    plt.imshow(normalized_image)
    plt.xlabel('Normalized Image')
    
    plt.subplot(2, 20, ncount)
    ncount = ncount + 1
    plt.hist(normalized_image.ravel(), 256, [0.0, 1.0])
    plt.xlabel('Normalized Image Histogram')
# Out:
# Showing sample of negative images from data

# %%
pcount = 1
for image in positive_selected_images:
    IMG = cv2.imread(os.path.join(new_folder_path, image))
    resized = cv2.resize(IMG, (250, 250))
    
    plt.figure(figsize = (80, 5))
    plt.subplot(2, 20, pcount)
    pcount = pcount + 1
    plt.imshow(resized)
    plt.xlabel('Image')

    plt.subplot(2, 20, pcount)
    pcount = pcount + 1
    plt.hist(resized.ravel(), 256, [0, 256])
    plt.xlabel('Histogram')
    
    normalized_image = resized/255.0
    plt.subplot(2, 20, pcount)
    pcount = pcount + 1
    plt.imshow(normalized_image)
    plt.xlabel('Normalized Image')
    
    plt.subplot(2, 20, pcount)
    pcount = pcount + 1
    plt.hist(normalized_image.ravel(), 256, [0.0, 1.0])
    plt.xlabel('Normalized Image Histogram')

# %% [markdown]
# #### Percentage of +ve and -ve in Sample

# %%
def get_percentage(sample, total):
    """
    This function will compute and return the percentage of a sample from the total amount
    Input Param 1 : Sample Selected
    Input Param 2 : Total Size  
    Output : Percentage of selected sample upto 2 dp
    """
    return round(sample / total * 100, 2)

# %%
total_selected_images = 10

# %%
percentage_of_negative_in_sample_ten = get_percentage(len(negative_selected_images), total_selected_images)
percentage_of_positive_in_sample_ten = get_percentage(len(positive_selected_images), total_selected_images)

print("Percentage of negative images in sample of 10 : ", percentage_of_negative_in_sample_ten)
print("Percentage of positive images in sample of 10 : ", percentage_of_positive_in_sample_ten)
# Out:
# Percentage of negative images in sample of 10 :  50.0
# Percentage of positive images in sample of 10 :  50.0

# %%
negative_images = []
positive_images = []

total_images = len(images)

for image in images:
    if (image[-5:] == "0.png"): # ends with 0.png means a negative sample
        negative_images.append(image)
    if (image[-5:] == "1.png"): # ends with 1.png means a positive sample
        positive_images.append(image)

percentage_of_negative = get_percentage(len(negative_images), total_images)
percentage_of_positive = get_percentage(len(positive_images), total_images)

print("Percentage of negative images in dataset : ", percentage_of_negative)
print("Percentage of positive images in dataset : ", percentage_of_positive)
# Out:
# Percentage of negative images in dataset :  71.61
# Percentage of positive images in dataset :  28.39

# %%
colors = ["#00876c", "#8ebf7f"]
fig, ax = plt.subplots(nrows=1, ncols=1)
labels = 'Cancer Positive', 'Cancer Negative'
ax.pie([percentage_of_negative, percentage_of_positive], startangle=90, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.f%%', explode=(0, 0.1), shadow=True)
ax.set_title('Ratio of cancer positive versus cancer negative datapoints in chosen datasets')
# Out:
# Text(0.5, 1.0, 'Ratio of cancer positive versus cancer negative datapoints in chosen datasets')
